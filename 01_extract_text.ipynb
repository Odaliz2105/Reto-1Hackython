# %% [markdown]
# Extraer texto de Pdfs

# %%
# !pip install PyPDF2 langchain langchain-community chromadb tiktoken openai python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip is available: 24.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting PyPDF2
#   Using cached pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: langchain in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (0.3.27)
# Requirement already satisfied: langchain-community in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (0.3.27)
# Collecting chromadb
#   Using cached chromadb-1.0.16-cp39-abi3-win_amd64.whl.metadata (7.5 kB)
# Requirement already satisfied: tiktoken in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (0.10.0)
# Requirement already satisfied: openai in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (1.99.1)
# Requirement already satisfied: python-dotenv in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (1.1.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (0.4.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (2.10.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-community) (2.1.3)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Using cached pybase64-1.4.2-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.22.1-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (0.21.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.2.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (3.11.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: idna>=2.8 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->openai) (2.10)
# Requirement already satisfied: packaging>=19.1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: certifi in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.36.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.36.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: greenlet>=1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from tokenizers>=0.13.2->chromadb) (0.33.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\odaliz aracely\appdata\roaming\python\python312\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Using cached chromadb-1.0.16-cp39-abi3-win_amd64.whl (19.6 MB)
# Using cached build-1.3.0-py3-none-any.whl (23 kB)
# Using cached kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
# Using cached mmh3-5.2.0-cp312-cp312-win_amd64.whl (41 kB)
# Using cached onnxruntime-1.22.1-cp312-cp312-win_amd64.whl (12.7 MB)
# Using cached opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.36.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.36.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.36.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Using cached opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Using cached pybase64-1.4.2-cp312-cp312-win_amd64.whl (35 kB)
# Using cached uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached watchfiles-1.1.0-cp312-cp312-win_amd64.whl (292 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pyreadline3, pyproject_hooks, PyPDF2, pybase64, pyasn1, overrides, opentelemetry-proto, oauthlib, mmh3, importlib-resources, importlib-metadata, httptools, googleapis-common-protos, backoff, watchfiles, uvicorn, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, humanfriendly, build, opentelemetry-semantic-conventions, google-auth, coloredlogs, opentelemetry-sdk, onnxruntime, kubernetes, opentelemetry-exporter-otlp-proto-grpc, chromadb
# Successfully installed PyPDF2-3.0.1 backoff-2.2.1 build-1.3.0 chromadb-1.0.16 coloredlogs-15.0.1 google-auth-2.40.3 googleapis-common-protos-1.70.0 httptools-0.6.4 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 kubernetes-33.1.0 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.22.1 opentelemetry-api-1.36.0 opentelemetry-exporter-otlp-proto-common-1.36.0 opentelemetry-exporter-otlp-proto-grpc-1.36.0 opentelemetry-proto-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 overrides-7.7.0 posthog-5.4.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.2 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9.1 uvicorn-0.35.0 watchfiles-1.1.0

# %%
import os
from PyPDF2 import PdfReader

INPUT_DIR = "data"
OUTPUT_DIR = "processed"

os.makedirs(OUTPUT_DIR, exist_ok=True)

def extract_text_from_pdf(pdf_path):
    text = ""
    with open(pdf_path, "rb") as f:
        reader = PdfReader(f)
        for page in reader.pages:
            text += page.extract_text() + "\n"
    return text

for folder in os.listdir(INPUT_DIR):
    folder_path = os.path.join(INPUT_DIR, folder)
    if os.path.isdir(folder_path):
        for file in os.listdir(folder_path):
            if file.endswith(".pdf"):
                input_path = os.path.join(folder_path, file)
                output_file = os.path.splitext(file)[0] + ".txt"
                output_path = os.path.join(OUTPUT_DIR, output_file)
                
                text = extract_text_from_pdf(input_path)
                with open(output_path, "w", encoding="utf-8") as out:
                    out.write(text)
                
                print(f"✅ Extraído: {file} → {output_file}")
# Out:
# ✅ Extraído: condiciones_particulares_del_contrato.pdf → condiciones_particulares_del_contrato.txt
# ✅ Extraído: formulario_unico_de_la_oferta.pdf → formulario_unico_de_la_oferta.txt
# ✅ Extraído: condiciones_particulares_del_pliego.pdf → condiciones_particulares_del_pliego.txt
